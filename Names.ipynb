# %%
import pandas as pd
import plotly
plotly.tools.set_credentials_file(username='shaktiman', api_key='J4QfqnW8wpnfNNMVSqX7')
import plotly.plotly as py
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

from os import listdir
from os.path import isfile,join
import csv
# %matplotlib inline
from matplotlib.pyplot import imshow
from scipy.misc import imread

def show_img(url):
    response = requests.get(url)
    imshow(imread(BytesIO(response.content)))

# %%
us_names = "./names/"
onlyfiles = [f for f in listdir(us_names) if isfile(join(us_names, f))]
year = []
name = []
sex = []
count = []
for i in onlyfiles:
    with open('names/'+i, 'r',encoding = "ISO-8859-1") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        for row in csv_reader:
            year.append(int(i[3:7]))
            name.append(row[0])
            sex.append(row[1])
            count.append(row[2])
    
us_name_df = pd.DataFrame({"year":year,"name":name,"sex":sex,"count":count})
us_name_df.head()
# Out:
#    year     name sex  count
# 0  2000    Emily   F  25953
# 1  2000   Hannah   F  23080
# 2  2000  Madison   F  19967
# 3  2000   Ashley   F  17997
# 4  2000    Sarah   F  17697

# %%
thrones = pd.read_csv("Thrones_charactor.csv")
thrones.columns.values
# Out:
# array([' name', 'season', 'appeared', 'status', 'deathcause', 'origin',
#        'houseallegiance', 'portrayed', 'culture', 'religion', 'gender',
#        'image'], dtype=object)

# %%
thrones_name = thrones[' name'].unique()
thrones_value = thrones['image'].unique()
print(len(thrones_name), len(thrones_value))
# thrones_first = [i.split(" ")[0] for i in thrones_name ]
# print(thrones_first)
# Out:
# 48 48

# %%
us_name_df1 = us_name_df[['name','sex','count']].groupby(['name','sex']).sum()

# %%
a = us_name_df[['year','name','sex','count']].groupby(['year','name','sex']).sum()
# a.to_csv("us_name.csv")
a.plot()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in f(self, **kwargs)
#    1421                     return self._cython_agg_general(
# -> 1422                         alias, alt=npfunc, **kwargs)
#    1423                 except AssertionError as e:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    3971         new_items, new_blocks = self._cython_agg_blocks(
# -> 3972             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
#    3973         return self._wrap_agged_blocks(new_items, new_blocks)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    4043         if len(new_blocks) == 0:
# ...

# %%
show_img(thrones.image[0])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning:
#
# `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
ar = a[a.name== thrones_name[0].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# <BarContainer object of 22 artists>

# %%
show_img(thrones.image[2])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning:
#
# `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[2])
ar = a[a.name== thrones_name[2].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Daenerys Targaryen
# <BarContainer object of 6 artists>

# %%
show_img(thrones.image[3])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning:
#
# `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[3])
ar = a[a.name== thrones_name[3].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Jon Snow
# <BarContainer object of 179 artists>

# %%
print(thrones_name[4])
ar = a[a.name== thrones_name[4].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Sansa Stark
# <BarContainer object of 5 artists>

# %%
# print(thrones_first)
plt.rcParams['figure.figsize'] = [50, 70]
ar = a[a.name.isin(thrones_first)]
plt.bar(ar.name.values, ar['count'])
# ar.name.unique()
# Out:
# <BarContainer object of 1428 artists>
