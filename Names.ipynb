# %% [markdown]
# # US Babies Name Analysis with Famous TV series Character

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import requests

import csv
# %matplotlib inline
from matplotlib.pyplot import imshow
from scipy.misc import imread
from io import BytesIO
def show_img(url):
    response = requests.get(url)
    imshow(imread(BytesIO(response.content)))

# %%
thrones = pd.read_csv("Thrones_charactor.csv")
thrones.columns.values
# Out:
# array([' name', 'season', 'appeared', 'status', 'deathcause', 'origin',
#        'houseallegiance', 'portrayed', 'culture', 'religion', 'gender',
#        'image'], dtype=object)

# %%
thrones_name = thrones[' name'].unique()
thrones_value = thrones['image'].unique()
print(len(thrones_name), len(thrones_value))
# thrones_first = [i.split(" ")[0] for i in thrones_name ]
# print(thrones_first)b
# Out:
# 48 48

# %%
us_df = pd.read_csv('us_name.csv')
us_df.head()
# Out:
#    year    name sex  count
# 0  1880   Aaron   M    102
# 1  1880      Ab   M      5
# 2  1880   Abbie   F     71
# 3  1880  Abbott   M      5
# 4  1880    Abby   F      6

# %%
show_img(thrones.image[0])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones[' name'][0])
ar = us_df[us_df.name== thrones_name[0].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Tyrion Lannister
# <BarContainer object of 22 artists>

# %%
show_img(thrones.image[2])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[2])
ar = us_df[us_df.name== thrones_name[2].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Daenerys Targaryen
# <BarContainer object of 6 artists>

# %%
show_img(thrones.image[3])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[3])
ar = us_df[us_df.name== thrones_name[3].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Jon Snow
# <BarContainer object of 179 artists>

# %%
show_img(thrones.image[4])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[4])
ar = us_df[us_df.name== thrones_name[4].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Sansa Stark
# <BarContainer object of 5 artists>

# %%
show_img('https://upload.wikimedia.org/wikipedia/en/3/39/Arya_Stark-Maisie_Williams.jpg')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[5])
ar = us_df[us_df.name== thrones_name[5].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Arya Stark
# <BarContainer object of 62 artists>

# %%
show_img(thrones.image[6])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[6])
ar = us_df[us_df.name== thrones_name[6].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Jorah Mormont
# <BarContainer object of 9 artists>

# %%
show_img(thrones.image[7])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[7])
ar = us_df[us_df.name== thrones_name[7].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Jaime Lannister
# <BarContainer object of 176 artists>

# %%
show_img(thrones.image[8])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
print(thrones_name[8])
ar = us_df[us_df.name== thrones_name[8].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Samwell Tarly
# <BarContainer object of 1 artists>

# %%
show_img(thrones.image[9])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=9
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Theon Greyjoy
# <BarContainer object of 30 artists>

# %%
show_img('https://upload.wikimedia.org/wikipedia/en/thumb/f/fa/Bran_Stark_-_Isaac_Hempstead-Wright.jpeg/220px-Bran_Stark_-_Isaac_Hempstead-Wright.jpeg')
# print(thrones.image[18])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=18
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Bran Stark
# <BarContainer object of 24 artists>

# %%
show_img(thrones.image[19])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=19
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Catelyn Stark
# <BarContainer object of 33 artists>

# %%
show_img(thrones.image[32])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=32
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Grey Worm
# <BarContainer object of 120 artists>

# %%
show_img(thrones.image[36])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=36
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Ramsay Bolton
# <BarContainer object of 52 artists>

# %%
show_img(thrones.image[33])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=43
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Shireen Baratheon
# <BarContainer object of 75 artists>

# %%
show_img(thrones.image[45])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=45
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Renly Baratheon
# <BarContainer object of 10 artists>

# %%
show_img('https://www.hbo.com/content/dam/hbodata/series/game-of-thrones/character/s5/oberyn-1920.jpg/_jcr_content/renditions/cq5dam.web.1200.675.jpeg')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
i=46
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
# Out:
# Oberyn Martell
# <BarContainer object of 3 artists>

# %%
# print(thrones_name[i])
ar = us_df[us_df.name == 'Kunal']
plt.bar(ar.year.values, ar['count'])
# Out:
# <BarContainer object of 39 artists>

# %%
ar = us_df[us_df.name== 'Aniket']
plt.bar(ar.year.values, ar['count'])

# %%
i=9
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])

# %%
i=9
print(thrones_name[i])
ar = us_df[us_df.name== thrones_name[i].split(" ")[0]]
plt.bar(ar.year.values, ar['count'])
